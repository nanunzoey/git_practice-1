# %% [markdown]
# # **LightFM 이용**

# %% [markdown]
# ## **Import Modules**

# %%
# !pip install lightfm
# !pip install scikit-optimize
# Out:
# Requirement already satisfied: lightfm in /usr/local/lib/python3.7/dist-packages (1.16)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from lightfm) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from lightfm) (0.22.2.post1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from lightfm) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from lightfm) (1.19.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->lightfm) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->lightfm) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->lightfm) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->lightfm) (1.24.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->lightfm) (1.0.1)
# Requirement already satisfied: scikit-optimize in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (0.22.2.post1)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (21.10.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyaml>=16.9->scikit-optimize) (3.13)

# %%
from google.colab import files
import os
import random
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from scipy.sparse import csr_matrix

from lightfm.cross_validation import random_train_test_split
from lightfm.evaluation import auc_score, precision_at_k, recall_at_k
from lightfm import LightFM
from skopt import forest_minimize

# %% [markdown]
# ## **데이터 로드**

# %%
file_path = "/content/drive/MyDrive/AIFFEL/해커톤3/모델 검증_토이데이터_211010"
book_path = file_path + '/goodreads_books_poetry.json.gz'
action_path = file_path + '/goodreads_interactions_poetry.json.gz'

book = pd.read_json(book_path, lines=True, compression='gzip')
action = pd.read_json(action_path, lines=True, compression='gzip')

# %%
print(book.shape)
print(action.shape)
# Out:
# (36514, 29)
# (2734350, 10)

# %%
book.head()
# Out:
#          isbn  ...                     title_without_series
# 0              ...    Vision of Sir Launfal and Other Poems
# 1  0811223981  ...                 Fairy Tales: Dramolettes
# 2  0374428115  ...  Growltiger's Last Stand and Other Poems
# 3  0156182890  ...                       The Cocktail Party
# 4  1942004192  ...          Louder Than Everything You Love
#
# [5 rows x 29 columns]

# %%
action.head()
# Out:
#                             user_id  ...  started_at
# 0  8842281e1d1347389f2ab93d60773d4d  ...
# 1  8842281e1d1347389f2ab93d60773d4d  ...
# 2  8842281e1d1347389f2ab93d60773d4d  ...
# 3  72fb0d0087d28c832f15776b0d936598  ...
# 4  72fb0d0087d28c832f15776b0d936598  ...
#
# [5 rows x 10 columns]

# %% [markdown]
# ## **데이터 전처리**

# %% [markdown]
# ##### - 사용하지 않을 column 제거

# %%
book_data = book.drop(['series', 'is_ebook', 'kindle_asin', 'description', 'link', 'isbn13', 'url', 'title_without_series', 'edition_information', 'work_id', 'isbn', 'asin', 'popular_shelves', 'authors', 'publisher', 'publication_day', 'publication_month', 'country_code', 'similar_books', 'language_code', 'format'], axis=1)

# %%
action[(action['is_read'] == False) & (action['rating'] != 0)]
# Out:
# Empty DataFrame
# Columns: [user_id, book_id, review_id, is_read, rating, review_text_incomplete, date_added, date_updated, read_at, started_at]
# Index: []

# %%
action_data = action.drop(['review_id', 'is_read', 'review_text_incomplete', 'date_added', 'date_updated', 'read_at', 'started_at'], axis=1)

# %% [markdown]
# ##### - missing value & 중복 처리

# %%
book_data.dropna(inplace=True)
action_data.dropna(inplace=True)

# %%
# book_data['language_code'].replace('', 'unknown', inplace=True)
# book_data['format'].replace('', 'no_format', inplace=True)
book_data['num_pages'].replace({'': -1, 0: -1}, inplace=True)
book_data['publication_year'].replace({'': 2100, 0: 2100}, inplace=True)

# %%
book_data.drop_duplicates(inplace=True)
action_data.drop_duplicates(inplace=True)

# %%
print(book_data.shape)
print(action_data.shape)
# Out:
# (36514, 8)
# (2734350, 3)

# %% [markdown]
# ##### - outlier 처리

# %%
book_data['publication_year'] = pd.to_numeric(book_data['publication_year'])
book_data['publication_year'].describe()
# Out:
# count    36514.000000
# mean      2016.818316
# std        107.055295
# min          0.000000
# 25%       2000.000000
# 50%       2009.000000
# 75%       2015.000000
# max      20012.000000
# Name: publication_year, dtype: float64

# %%
book_data['publication_year'].plot.box()

# %%
book_data[(book_data['publication_year'] > 2100) | (book_data['publication_year'] <= 1000)]
# Out:
#        text_reviews_count  ...                        title
# 6047                    1  ...                         Odes
# 6234                    1  ...  The Poems of Anyte of Tegea
# 9600                    4  ...            Ang Hayop na Ito!
# 17573                   1  ...         Laberinto de Fortuna
# 17667                   2  ...   A Child's Garden of Verses
# 17784                   1  ...                Patria mea A4
# 18308                   4  ...             Estremelenggoles
# 21823                   1  ...            Orpheus’a Soneler
#
# [8 rows x 8 columns]

# %%
book_data['publication_year'][21823] = 2012

book_data['publication_year'][6047, 9600, 18308] = 2100

# %%
book_data.drop([17573, 17784], axis=0, inplace=True)

# %%
book_data['publication_year'].describe()
# Out:
# count    36512.000000
# mean      2016.421724
# std         48.985190
# min          0.000000
# 25%       2000.000000
# 50%       2009.000000
# 75%       2015.000000
# max       2100.000000
# Name: publication_year, dtype: float64

# %% [markdown]
# ##### - categorical column 처리

# %%
book_data['ratings_count'].describe()
# Out:
# count    3.651200e+04
# mean     2.797025e+02
# std      7.633623e+03
# min      0.000000e+00
# 25%      9.000000e+00
# 50%      2.300000e+01
# 75%      6.900000e+01
# max      1.029527e+06
# Name: ratings_count, dtype: float64

# %%
book_data['num_pages'] = pd.to_numeric(book_data['num_pages'])
book_data['num_pages'].describe()
# Out:
# count    36512.000000
# mean       148.868509
# std        208.713169
# min         -1.000000
# 25%         33.750000
# 50%         96.000000
# 75%        188.000000
# max      10960.000000
# Name: num_pages, dtype: float64

# %%
book_data = book_data.sort_values('book_id').reset_index(drop=True)

book_data.head()
# Out:
#    text_reviews_count  ...                                           title
# 0                  24  ...           The Complete Verse and Other Nonsense
# 1                  30  ...            The Complete Nonsense of Edward Lear
# 2                  51  ...                         A Was Once an Apple Pie
# 3                   6  ...               The Puffin Book Of Nonsense Verse
# 4                  54  ...  The Time of the Assassins:  a Study of Rimbaud
#
# [5 rows x 8 columns]

# %%
book_final = book_data.drop(['title', 'image_url'], axis=1).copy()

# %%
# using pandas qcut method to convert fields into quantile-based discrete intervals
book_final['text_reviews_count'] = pd.qcut(book_final['text_reviews_count'], 20, duplicates='drop')
book_final['ratings_count'] = pd.qcut(book_final['ratings_count'], 25)
book_final['publication_year'] = pd.qcut(book_final['publication_year'], 20, duplicates='drop')
book_final['num_pages'] = pd.qcut(book_final['num_pages'], 20, precision=0, duplicates='drop')

# rounding ratings to neares .5 score
book_final['average_rating'] = book_final['average_rating'].apply(lambda x: round(x*2)/2)

# %%
book_final.head()
# Out:
#   text_reviews_count  average_rating  ... book_id       ratings_count
# 0       (23.0, 44.0]             4.0  ...     234  (614.0, 1029527.0]
# 1       (23.0, 44.0]             4.0  ...     236      (285.0, 614.0]
# 2    (44.0, 10403.0]             3.5  ...     241      (125.0, 179.0]
# 3         (5.0, 6.0]             4.0  ...     244        (59.0, 73.0]
# 4    (44.0, 10403.0]             4.0  ...     254  (614.0, 1029527.0]
#
# [5 rows x 6 columns]

# %%
# dummify categorical features
book_final = pd.get_dummies(book_final, columns=['text_reviews_count', 'average_rating', 'num_pages', 'publication_year', 'ratings_count'])

# %%
book_final.sample(5)
# Out:
#         book_id  ...  ratings_count_(614.0, 1029527.0]
# 26798  17824924  ...                                 0
# 26238  17342451  ...                                 0
# 25919  17186502  ...                                 0
# 26779  17800801  ...                                 0
# 9678    1281422  ...                                 0
#
# [5 rows x 82 columns]

# %%
action_final = action_data.copy()

# %%
action_final = action_final[action_final['rating'] != 0]

# %%
print(book_final.shape)

print(action_data.shape)
print(action_final.shape)
# Out:
# (36512, 82)
# (2734350, 3)
# (1229059, 3)

# %% [markdown]
# ## **CSR Matrix 생성**

# %% [markdown]
# ##### - item dictionary 생성

# %%
df = book_data[['book_id', 'title', 'image_url']]
df.reset_index(inplace=True)

# %%
df
# Out:
#        index  ...                                          image_url
# 0          0  ...  https://s.gr-assets.com/assets/nophoto/book/11...
# 1          1  ...  https://s.gr-assets.com/assets/nophoto/book/11...
# 2          2  ...  https://images.gr-assets.com/books/1328868141m...
# 3          3  ...  https://images.gr-assets.com/books/1356458077m...
# 4          4  ...  https://s.gr-assets.com/assets/nophoto/book/11...
# ...      ...  ...                                                ...
# 36507  36507  ...  https://images.gr-assets.com/books/1508097504m...
# 36508  36508  ...  https://s.gr-assets.com/assets/nophoto/book/11...
# 36509  36509  ...  https://images.gr-assets.com/books/1509740993m...
# 36510  36510  ...  https://s.gr-assets.com/assets/nophoto/book/11...
# 36511  36511  ...  https://images.gr-assets.com/books/1509098580m...
#
# [36512 rows x 4 columns]

# %%
item_dict = {}

for i in range(df.shape[0]):
    item_dict[(df.loc[i,'book_id'])] = [df.loc[i,'title'], df.loc[i, 'image_url']]

# %%
item_dict[36418610]
# Out:
# ['Den vita rosen',
#  'https://images.gr-assets.com/books/1508097504m/36418610.jpg']

# %% [markdown]
# ##### - train, test 데이터셋 split -> csr matrix 생성

# %%
book_csr = csr_matrix(book_final.drop('book_id', axis=1).values)
book_csr
# Out:
# <36512x81 sparse matrix of type '<class 'numpy.uint8'>'
# 	with 182560 stored elements in Compressed Sparse Row format>

# %%
action_final.shape
# Out:
# (1229059, 3)

# %%
action_sample = action_final.loc[action_final['user_id'].isin(random.sample(list(action_final['user_id'].unique()), k=10000))]

# %%
action_sample.head()
# Out:
#                              user_id  book_id  rating
# 88  8489357f2f485c1a961d4cbdc54ea84b    30119       3
# 90  8489357f2f485c1a961d4cbdc54ea84b    12914       3
# 92  8489357f2f485c1a961d4cbdc54ea84b     1381       5
# 93  8489357f2f485c1a961d4cbdc54ea84b     1519       4
# 94  8489357f2f485c1a961d4cbdc54ea84b    32552       4

# %%
# interaction matrix
interaction = pd.pivot_table(action_sample, index='user_id', columns='book_id', values='rating')

# fill missing values with 0
interaction = interaction.fillna(0)

interaction.head()
# Out:
# book_id                           234       236       ...  36232007  36417323
# user_id                                               ...
# 00130b2e4d35f9b0edee72c620d9a687       0.0       0.0  ...       0.0       0.0
# 001aa4da5b2c1c53765b168224c7f106       0.0       0.0  ...       0.0       0.0
# 00256a2c71f40fc50a7ae5fcff55a502       0.0       0.0  ...       0.0       0.0
# 0026d40516cf87689bf9d009e3fe2609       0.0       0.0  ...       0.0       0.0
# 002c3e87a952e89338cdf4a9e9b98a2d       0.0       0.0  ...       0.0       0.0
#
# [5 rows x 9999 columns]

# %%
user_id = list(interaction.index)

user_dict = {}
counter = 0

for i in user_id:
  user_dict[i] = counter
  counter += 1

# %%
# convert to csr matrix
interaction_csr = csr_matrix(interaction.values)
interaction_csr
# Out:
# <10000x9999 sparse matrix of type '<class 'numpy.float64'>'
# 	with 45082 stored elements in Compressed Sparse Row format>

# %%
# train, test split
train_interaction_csr, test_interaction_csr = random_train_test_split(interaction_csr, test_percentage=0.2)

# %% [markdown]
# ## **Model Train & Validate**

# %%
model = LightFM(loss='warp',
                random_state=2021,
                learning_rate=0.90,
                no_components=150,
                user_alpha=0.000005)

model = model.fit(train_interaction_csr,
                  epochs=100,
                  num_threads=16, verbose=False)

# %%
auc_train = auc_score(model, train_interaction_csr, num_threads=16).mean()
auc_test = auc_score(model, test_interaction_csr, num_threads=16).mean()

# %%
print(auc_train)
print(auc_test)
# Out:
# 0.6098849
# 0.5206513
